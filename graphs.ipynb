# %%
import plotly.graph_objects as go
import pandas as pd

# Base data
data = {
    "Year": list(range(2000, 2036)),
    "Network_Electricity_Usage_TWh": [
        141.894855, 148.2371723, 178, 162.9657579, 171.5000731, 180.9266839, 191.3413414,
        203, 219, 229.6350819, 185, 220, 334, 454, 470, 247, 521, 551, 362, 368, 379, 354,
        427, 526, 656, 538.363593, 555.528482, 572.693371, 589.85826, 607.023149, 624.188037,
        641.352926, 658.517815, 675.682704, 692.847593, 710.012482
    ],
    "Enterprise_Network_Electricity_Usage_TWh": [
        21.00565577, 21.04940654, 21.0939647, 21.13939625, 21.18577285, 21.23317237,
        21.2816794, 29, 21.382392, 21.43480639, 21.48874753, 11, 21.60173717, 21.66107901,
        21.72253654, 21.78629151, 21.85254211, 21.92150464, 21.99341515, 22.06853141, 25,
        22.23709711, 22.31660693, 22.438411, 22.52416364, 22.60361285, 22.70115795,
        22.81519469, 22.98280967, 23.09730126, 23.21819584, 23.30170177, 23.44404743,
        23.63871491, 23.88717793, 24.0884602
    ],
    "Data_Center_Electricity_Usage_TWh": [
        186.45511, 186.990924, 152, 185.561585, 184.733436, 184.347874, 184.598878,
        180, 254, 194.557379, 196.697093, 237, 268, 239.843959, 250.7613, 220, 271.635739,
        279.523457, 211, 208, 207, 202, 239, 287, 347, 275.079758, 279.139103, 283.198448,
        287.257794, 291.317139, 295.376484, 299.43583, 303.495175, 307.55452, 311.613865,
        315.673211
    ],
    "ICT_Devices_Electricity_Usage_TWh": [
        238, 243, 480, 254, 260, 265, 273, 260, 263, 297, 249, 335, 307, 317, 344, 343, 399,
        427, 474, 400, 522, 515, 525, 538, 556, 573, 586, 607, 636, 681, 743, 809, 879, 951,
        1019, 1085
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Create figure
fig = go.Figure()

# Add each category as a line
fig.add_trace(go.Scatter(x=df["Year"], y=df["Network_Electricity_Usage_TWh"],
                         mode='lines+markers', name='Network'))
fig.add_trace(go.Scatter(x=df["Year"], y=df["Enterprise_Network_Electricity_Usage_TWh"],
                         mode='lines+markers', name='Enterprise Network'))
fig.add_trace(go.Scatter(x=df["Year"], y=df["Data_Center_Electricity_Usage_TWh"],
                         mode='lines+markers', name='Data Centers'))
fig.add_trace(go.Scatter(x=df["Year"], y=df["ICT_Devices_Electricity_Usage_TWh"],
                         mode='lines+markers', name='ICT Devices'))

# Update layout
fig.update_layout(
    #title="ICT Sector Electricity Usage by Category (2000–2035)",
    xaxis_title="Year",
    yaxis_title="Electricity Usage (TWh)",
    hovermode='x unified',
    template='plotly_white'
)

fig.show()

# %%
import plotly.graph_objects as go
import pandas as pd

# Data
data = {
    "Year": list(range(2000, 2036)),
    "Network_emission_MtCO2e": [
        131.59, 134.09, 151, 140.82, 144.20, 147.64, 151.52, 307.1, 159.11, 162.59, 144, 190.5,
        195.83, 193.77, 190.71, 180, 184.01, 181.13, 173, 181.56, 186, 177.59, 190.44, 213.52,
        241.71, 221.33, 225.90, 230.53, 235.83, 241.62, 248.98, 244.80, 248.45, 253.01, 257.34, 262.02
    ],
    "Enterprise_network_emission_MtCO2e": [
        13.34, 13.36, 13.39, 13.41, 13.44, 13.46, 13.49, 17, 13.54, 13.91, 14.46, 9.5,
        14.52, 14.55, 14.66, 14.7, 14.93, 14.86, 16, 14.94, 16, 15.03, 15.08, 15.14,
        15.19, 15.23, 15.28, 15.34, 15.43, 15.5, 15.56, 15.61, 15.68, 15.79, 15.92, 16.03
    ],
    "Data_Center_emission_MtCO2e": [
        95.97, 97.08, 76, 102.16, 105.50, 109.14, 113.09, 116.2, 163.98, 124.57, 133.94, 160,
        185.18, 169.29, 176.51, 165, 189.11, 192.95, 129, 131.86, 125, 113.04, 121.30, 152.18,
        168.27, 187.91, 210.11, 236.48, 268.78, 307.00, 350.88, 379.54, 392.03, 389.95, 390.08, 385.55
    ],
    "ICT_Devices_emission_MtCO2e": [
        316.17, 309.49, 303, 298.16, 296.60, 303.63, 300.91, 326.52, 339.59, 337.56, 359.25, 369.9,
        412.99, 399.51, 406.85, 400, 390.65, 357.65, 337.58, 356.90, 436, 446.15, 359.92, 310.24,
        375.34, 357.12, 332.32, 342.01, 341.18, 333.01, 339.30, 343.96, 328.43, 324.71, 341.59, 346.28
    ]
}

# Create DataFrame
df = pd.DataFrame(data)

# Plot
fig = go.Figure()
fig.add_trace(go.Scatter(x=df["Year"], y=df["Network_emission_MtCO2e"],
                         mode='lines+markers', name='Network'))
fig.add_trace(go.Scatter(x=df["Year"], y=df["Enterprise_network_emission_MtCO2e"],
                         mode='lines+markers', name='Enterprise Network'))
fig.add_trace(go.Scatter(x=df["Year"], y=df["Data_Center_emission_MtCO2e"],
                         mode='lines+markers', name='Data Center'))
fig.add_trace(go.Scatter(x=df["Year"], y=df["ICT_Devices_emission_MtCO2e"],
                         mode='lines+markers', name='ICT Devices'))

fig.update_layout(
    #title="Carbon Footprint of ICT Components (2000–2035)",
    xaxis_title="Year",
    yaxis_title="Emissions (Mt CO₂e)",
    hovermode='x unified',
    template='plotly_white'
)

fig.show()

# %%
import plotly.graph_objects as go

# Base data
years_base = list(range(2000, 2036))
electricity_base = [
    587.3556207, 599.2775028, 810, 623.6667391, 637.4192819, 651.5077303,
    670.2218988, 643, 736, 742.6272673, 652.1858405, 792, 909,
    1032.505038, 1086.483837, 810, 1213.488281, 1279.444962, 836,
    998.0685314, 859, 1093.237097, 1213.316607, 1373.438411, 1581.524164,
    1409.046964, 1443.368743, 1485.707014, 1536.098864, 1602.437589,
    1685.782717, 1773.090458, 1864.457037, 1957.875939, 2047.348636,
    2134.774153
]

# Scatter data
scatter_years = [
    2002, 
    2007, 2007, 
    2008, 2008, 
    2010, 2010, 
    2011, 2011, 2011, 
    2012, 2012, 2012, 
    2013, 2013, 
    2014, 2014, 
    2015, 2015, 2015, 
    2016, 2016, 
    2017, 2017,
    2018, 2018, 2018, 
    2019, 2019, 
    2020, 2020, 2020, 2020, 2020, 2020,
    2021, 2021, 
    2022, 2022, 
    2023, 2023, 
    2024, 2024, 
    2025, 2025, 
    2026, 2026,
    2027, 2027, 
    2028, 2028, 
    2029, 2029, 
    2030, 2030, 2030, 2030
]
scatter_electricity = [
    810, 
    643, 710, 
    736, 1471.68, 
    1538, 2037, 
    792, 1539, 2073, 
    909, 1579,
    2164, 1543, 2191, 
    1522, 2243, 
    803, 1509, 
    2312, 1495, 2391, 
    1487, 2476,
    836, 1490, 
    2589, 1497, 2723, 
    859, 1300, 
    3766.8, 1507, 2878, 1900, 1487, 3010, 
    1544, 3260, 
    1611, 3562, 
    1700, 3920, 
    1810, 4350, 
    1942, 4858,
    2097, 5480, 
    2276, 6237, 
    2477, 7155, 
    1500, 2698, 8265, 3200
]

# Create the figure
fig = go.Figure()

# Line plot for base data
fig.add_trace(go.Scatter(
    x=years_base,
    y=electricity_base,
    mode='lines+markers',
    name='Estimations of this study',
    line=dict(color='royalblue', width=3),
    marker=dict(size=6)
))

# Scatter plot for additional data
fig.add_trace(go.Scatter(
    x=scatter_years,
    y=scatter_electricity,
    mode='markers',
    name='Calculations of other studies',
    marker=dict(color='firebrick', size=8, symbol='x'),
    hovertemplate='Year: %{x}<br>Electricity: %{y} TWh'
))

# Customize layout
fig.update_layout(
    #title='Electricity Footprint of ICT (2000–2035) with Additional Consumption Points',
    xaxis_title='Year',
    yaxis_title='Electricity (TWh)',
    hovermode='x unified',
    template='plotly_white',
    width=1100,
    height=600,
    legend=dict(x=0.01, y=0.99)
)

fig.show()

# %%
import plotly.graph_objects as go

# Base data
years = list(range(2000, 2036))
emissions = [
    557.0727671,
554.0266667,
530,
554.5443058,
559.735274,
573.8774421,
579.008513,
620,
676.2269222,
638.6269201,
720,
731,
808.5195876,
777.1203066,
788.7212435,
745,
778.7006785,
746.5934491,
705,
685.2728998,
763,
751.8076087,
686.7430506,
691.0703387,
800.5148174,
781.5932659,
783.6143376,
824.3642924,
861.2269711,
897.1190884,
954.7255498,
983.8999736,
984.5884773,
983.4588124,
1004.931162,
1009.88743,
]

# Scatter point data
scatter_years = [2002,
                2007, 2007, 2007, 2007, 2007,
                2010, 2010, 2010,
                2011, 2011, 2011,
                2012, 2012, 2012, 2012,
                2013, 2013,
                2014, 2014,
                2015, 2015, 2015, 2015, 2015, 2015,
                2016, 2016,
                2017, 2017, 
                2018, 2018, 2018, 
                2019, 2019,  
                2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 
                2021, 2021, 2021,
                2022, 2022, 2022, 
                2023, 2023, 
                2024, 2024, 
                2025, 2025, 
                2026, 2026, 
                2027, 2027,
                2028, 2028, 
                2029, 2029, 
                2030, 2030, 2030
                ]
scatter_emissions = [530,
                    620, 830, 1150, 454, 444, 
                    720, 1000, 1300,
                    910, 1000, 1300,
                    630, 616, 1000, 1300,
                    900, 1300,
                    900, 1400, 
                    733, 971, 775, 873, 1410, 917,
                    900, 1500, 
                    900, 1500,
                    705, 900, 1600, 
                    900, 1600,
                    1430, 1270, 1100, 690, 1107, 1306, 1206, 887, 1860, 568,
                    589, 900, 1800,
                    567, 900, 1900,
                    900, 2100,
                    1000, 2300,
                    1000, 2500,
                    1100, 2800,
                    1200, 3200,
                    1300, 3600,
                    1400, 4100,
                    1250, 1500, 4800
                    ]

# Create the figure
fig = go.Figure()

# Line + markers plot
fig.add_trace(go.Scatter(
    x=years,
    y=emissions,
    mode='lines+markers',
    name='Estimations of this study',
    line=dict(color='royalblue', width=3),
    marker=dict(size=6)
))

# Scatter points
fig.add_trace(go.Scatter(
    x=scatter_years,
    y=scatter_emissions,
    mode='markers',
    name='Calculations of other studies',
    marker=dict(color='firebrick', size=8, symbol='x'),
    hovertemplate='Year: %{x}<br>Emissions: %{y} Mt CO2e'
))

# Layout customization
fig.update_layout(
    #title='ICT GHG Emissions (2000–2035) with Additional Data Points',
    xaxis_title='Year',
    yaxis_title='Emissions (Mt CO2e)',
    hovermode='x unified',
    template='plotly_white',
    width=1000,
    height=550,
    legend=dict(x=0.01, y=0.99)
)

fig.show()
